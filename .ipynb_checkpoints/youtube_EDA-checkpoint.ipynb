# %% [markdown]
# Inspiration from Thu Vu https://github.com/thu-vu92/youtube-api-analysis

# %%
#data manipulation
import pandas as pd
import numpy as np
from dateutil import parser
import isodate

#data visualization
import seaborn as sns
import matplotlib.pyplot as plt

sns.color_palette('colorblind')
# %matplotlib inline

#NLP lib
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#nltk.download('stopwords')
#nltk.download('punkt')
from wordcloud import WordCloud

# %% [markdown]
# ## Reading extracted DataFrames

# %%
ch_df = pd.read_csv('channel_df.csv')

# %%
ch_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          13 non-null     int64
#  1   channel_title       13 non-null     object
#  2   channel_desc        10 non-null     object
#  3   channel_view        13 non-null     int64
#  4   channel_sub         13 non-null     int64
#  5   channel_video       13 non-null     int64
#  6   channel_playlistId  13 non-null     object
# dtypes: int64(4), object(3)
# memory usage: 856.0+ bytes

# %%
ch_df.head(5)
# Out:
#    Unnamed: 0                         channel_title  \
# 0           0                        Peak Performer
# 1           1                           Iwona Golab
# 2           2                          PointyFloppy
# 3           3                          absoluteDogs
# 4           4  Zak George’s Dog Training Revolution
#
#                                         channel_desc  channel_view  \
# 0                                                NaN        300423
# 1  🌎Agility Worldwide Coach 🏆World Championship M...        210693
# 2  Adventure of border collies with pointy and fl...          2005
# 3  This is the official YouTube channel of Tom an...       1019301
# 4  This is the official YouTube channel of me, do...     272563458
#
#    channel_sub  channel_video        channel_playlistId
# 0         1550            488  UUEaf-PDONb_nhyNRmVw9_nA
# 1         1440            251  UUxXnIktVdXrSFCE8u1D-26w
# 2            9             58  UUSPfJ89aYsRhpDSnZ0vaFCg
# 3        47600            234  UUrz5NqpcLxpiy1Wm_ksEV3g
# 4      3560000            546  UUZzFRKsgVMhGTxffpzgTJlQ

# %%
ch_df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
ch_df.head(5)
# Out:
#                           channel_title  \
# 0                        Peak Performer
# 1                           Iwona Golab
# 2                          PointyFloppy
# 3                          absoluteDogs
# 4  Zak George’s Dog Training Revolution
#
#                                         channel_desc  channel_view  \
# 0                                                NaN        300423
# 1  🌎Agility Worldwide Coach 🏆World Championship M...        210693
# 2  Adventure of border collies with pointy and fl...          2005
# 3  This is the official YouTube channel of Tom an...       1019301
# 4  This is the official YouTube channel of me, do...     272563458
#
#    channel_sub  channel_video        channel_playlistId
# 0         1550            488  UUEaf-PDONb_nhyNRmVw9_nA
# 1         1440            251  UUxXnIktVdXrSFCE8u1D-26w
# 2            9             58  UUSPfJ89aYsRhpDSnZ0vaFCg
# 3        47600            234  UUrz5NqpcLxpiy1Wm_ksEV3g
# 4      3560000            546  UUZzFRKsgVMhGTxffpzgTJlQ

# %%
ch_df['view_per_video'] = ch_df['channel_view'] / ch_df['channel_video']

# %%
ch_df.sort_values(by='view_per_video',ascending=False)
# Out:
#                            channel_title  \
# 4   Zak George’s Dog Training Revolution
# 8                Dog Training by Kikopup
# 9                              Dogs That
# 11                        Tereza Králová
# 7                             Jenny Damm
# 3                           absoluteDogs
# 12                    Agile Dog Training
# 10                            Fanny Gott
# 6                            OneMindDogs
# 5                    McCann Dogs Agility
# 1                            Iwona Golab
# 0                         Peak Performer
# 2                           PointyFloppy
#
#                                          channel_desc  channel_view  \
# 4   This is the official YouTube channel of me, do...     272563458
# 8   Professional dog training videos created by wo...      41563688
# 9   Our DogsThat YouTube Channel is brought to you...       2128254
# 11                                                NaN        919462
# 7                                                 NaN        796472
# 3   This is the official YouTube channel of Tom an...       1019301
# 12  Welcome to the Agile Dog Training channel wher...         54951
# 10                            Clicker training videos       1466398
# 6   OneMind Dogs is a dog and agility training met...        995572
# 5   Kayl McCann is a dog trainer, who has been a m...        165365
# 1   🌎Agility Worldwide Coach 🏆World Championship M...        210693
# 0                                                 NaN        300423
# 2   Adventure of border collies with pointy and fl...          2005
#
#     channel_sub  channel_video        channel_playlistId  view_per_video
# 4       3560000            546  UUZzFRKsgVMhGTxffpzgTJlQ   499200.472527
# 8        358000            595  UU-qnqaajTk6bfs3UZuue6IQ    69854.937815
# 9         43700            291  UUC17PDLl8y1dP2BRV5vuseg     7313.587629
# 11         5730            138  UUmLiE85jsHD7tSsfGUoFd1A     6662.768116
# 7          5730            175  UUwLs3Ldbl1Ox-fvupUq7ipA     4551.268571
# 3         47600            234  UUrz5NqpcLxpiy1Wm_ksEV3g     4355.987179
# 12         2030             13  UUxsOQBtCjUhYS-j8VYt4KFQ     4227.000000
# 10         7130            413  UUqw_HGVtWKcd-owWODwcQsg     3550.600484
# 6          6380            370  UUMF2E-huI3T7meqJBU-olZg     2690.735135
# 5          4580            129  UUULyOKD5Y9QTKFDikg2UDgw     1281.899225
# 1          1440            251  UUxXnIktVdXrSFCE8u1D-26w      839.414343
# 0          1550            488  UUEaf-PDONb_nhyNRmVw9_nA      615.620902
# 2             9             58  UUSPfJ89aYsRhpDSnZ0vaFCg       34.568966

# %% [markdown]
# We can separate our analysis by channel type based on numbers of subscribers

# %% [markdown]
# __Premium tier (sub > 100,000)__
# - Zak George's Dog Training Revolution
# - Dog Training by Kikopup
#
# __Normal tier (sub <= 100,000)__
# - The rest

# %%
ch_df_normal = ch_df[ch_df['channel_sub'] <= 100000]

# %%
ch_df_premium = ch_df[ch_df['channel_sub'] > 100000]

# %% [markdown]
# Created channel title list (separate tier)

# %%
normal_ch = ch_df_normal['channel_title']

# %% [markdown]
# Now we can work with ch_df_normal and ch_df_premium separately

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
plt.title('Dog Training Channel Ranked by Channel Video')
sns.barplot(x='channel_title',y='channel_video',data = ch_df_normal.sort_values('channel_video',ascending=False))
# Out:
# <AxesSubplot:title={'center':'Dog Training Channel Ranked by Channel Video'}, xlabel='channel_title', ylabel='channel_video'>

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
plt.title('Dog Training Channel Ranked by Subscribers')
sns.barplot(x='channel_title',y='channel_sub',data = ch_df_normal.sort_values('channel_sub',ascending=False)[2::])
# Out:
# <AxesSubplot:title={'center':'Dog Training Channel Ranked by Subscribers'}, xlabel='channel_title', ylabel='channel_sub'>

# %%
plt.figure(figsize=(4,6))
plt.xticks(rotation=90)
plt.title('Dog Training Channel Ranked by Subscribers')
sns.barplot(x='channel_title',y='channel_sub',data = ch_df.sort_values('channel_sub',ascending=False)[0:5])
# Out:
# <AxesSubplot:title={'center':'Dog Training Channel Ranked by Subscribers'}, xlabel='channel_title', ylabel='channel_sub'>

# %%
#excluding the top two outliers - we will investigate the channel sub vs channel views
plt.figure(figsize=(10,6))
sns.lmplot(x='channel_sub', y='channel_view', data = ch_df_normal.sort_values(by='channel_sub',ascending=True)).set(title='Channel views vs channel subscribers')

# %% [markdown]
# Seems like there is a correlation

# %% [markdown]
# ## Data Preparation on video DataFrame (focusing only on normal tier for now)

# %%
df = pd.read_csv('video_df.csv')

# %%
df.shape
# Out:
# (3701, 13)

# %% [markdown]
# #### Check for empty values

# %%
df.isnull().sum() / len(df['video_id']) * 100
# Out:
# video_id          0.000000
# channelTitle      0.000000
# title             0.000000
# description      12.348014
# tags             27.100784
# publishedAt       0.000000
# duration          0.000000
# definition        0.000000
# caption           0.000000
# viewCount         0.000000
# likeCount         0.081059
# favoriteCount     0.000000
# commentCount      0.675493
# dtype: float64

# %%
df.isnull().sum()
# Out:
# video_id            0
# channelTitle        0
# title               0
# description       457
# tags             1003
# publishedAt         0
# duration            0
# definition          0
# caption             0
# viewCount           0
# likeCount           3
# favoriteCount       0
# commentCount       25
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),cmap='magma')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Since this data is acquired through API, we can fill in empty values with a specific words like "No description", "0 tags"
# But let's investigate no likeCount and no commentCount - as these should be nulls too

# %%
df[df['likeCount'].isnull()].head(3)
# Out:
#          video_id             channelTitle  \
# 2613  6INllFeO19k  Dog Training by Kikopup
# 3563  MANZ9_b__g0           Tereza Králová
# 3646  LEvUD2GPGYY           Tereza Králová
#
#                                       title  \
# 2613   Dog Training seminar in Venice Italy
# 3563           High´s first competition :-)
# 3646  Flame_Czech Agility Championship 2012
#
#                                             description  \
# 2613  Visit our website: http://dogmantics.com/\nBuy...
# 3563                                                NaN
# 3646  Just Flame Perla z Polabí & Tereza Králová\n1s...
#
#                                                    tags           publishedAt  \
# 2613  ['dog training', 'professional dog trainer', '...  2012-05-25T17:46:14Z
# 3563                                                NaN  2019-12-27T16:11:38Z
# 3646                               ['Flame', 'MČR2012']  2012-11-14T16:09:19Z
#
#      duration definition  caption  viewCount  likeCount  favoriteCount  \
# 2613  PT2M33S         sd    False       6828        NaN              0
# 3563  PT1M27S         hd    False       7171        NaN              0
# 3646  PT2M39S         sd    False       1946        NaN              0
#
#       commentCount
# 2613          28.0
# 3563           3.0
# 3646           0.0

# %%
df[df['commentCount'].isnull()].head(3)
# Out:
#         video_id    channelTitle  \
# 188  53omDafFkOA  Peak Performer
# 210  OJ59U9al2Fw  Peak Performer
# 211  8rRzz6okxNQ  Peak Performer
#
#                                                  title         description  \
# 188  10DEZ2015 – 2on2off und Running Contacts mit R...  www.swiss-paws.com
# 210                                     wand vergleich  www.swiss-paws.com
# 211                                          Mein Film  www.swiss-paws.com
#
#                              tags           publishedAt duration definition  \
# 188  ['swiss', 'paws', 'sheltie']  2015-12-10T15:44:00Z    PT49S         hd
# 210  ['swiss', 'paws', 'sheltie']  2015-04-18T20:59:51Z    PT57S         hd
# 211  ['swiss', 'paws', 'sheltie']  2015-04-18T20:07:50Z  PT3M54S         hd
#
#      caption  viewCount  likeCount  favoriteCount  commentCount
# 188    False        776        3.0              0           NaN
# 210    False        194        1.0              0           NaN
# 211    False        252        1.0              0           NaN

# %% [markdown]
# They are videos where likes and comments are turned off. So we will replace these with 0 (int) to correct data type

# %%
df['likeCount'].fillna(int(0),inplace=True)

# %%
df['commentCount'].fillna(int(0),inplace=True)

# %%
df.isnull().sum()
# Out:
# video_id            0
# channelTitle        0
# title               0
# description       457
# tags             1003
# publishedAt         0
# duration            0
# definition          0
# caption             0
# viewCount           0
# likeCount           0
# favoriteCount       0
# commentCount        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3701 entries, 0 to 3700
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       3701 non-null   object
#  1   channelTitle   3701 non-null   object
#  2   title          3701 non-null   object
#  3   description    3244 non-null   object
#  4   tags           2698 non-null   object
#  5   publishedAt    3701 non-null   object
#  6   duration       3701 non-null   object
#  7   definition     3701 non-null   object
#  8   caption        3701 non-null   bool
#  9   viewCount      3701 non-null   int64
#  10  likeCount      3701 non-null   float64
#  11  favoriteCount  3701 non-null   int64
#  12  commentCount   3701 non-null   float64
# dtypes: bool(1), float64(2), int64(2), object(8)
# memory usage: 350.7+ KB

# %%
df.isnull().sum()
# Out:
# video_id            0
# channelTitle        0
# title               0
# description       457
# tags             1003
# publishedAt         0
# duration            0
# definition          0
# caption             0
# viewCount           0
# likeCount           0
# favoriteCount       0
# commentCount        0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),cmap='magma')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Check what's up with tags

# %%
df['tags']
# Out:
# 0       ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 1       ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 2       ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 3       ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 4       ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
#                               ...
# 3696    ['agile dog training', 'dog agility training',...
# 3697    ['agile dog training', 'jess martin agility', ...
# 3698    ['agile dog training', 'jess martin agility', ...
# 3699    ['dog agility training', 'agile dog training',...
# 3700    ['dog agility training', 'agility start line',...
# Name: tags, Length: 3701, dtype: object

# %%
df['description'].fillna('No Description',inplace=True)

# %%
df['tags'].fillna('[]',inplace=True)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),cmap='magma')
# Out:
# <AxesSubplot:>

# %% [markdown]
# All data's are filled!

# %% [markdown]
# #### Now I need to check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3701 entries, 0 to 3700
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       3701 non-null   object
#  1   channelTitle   3701 non-null   object
#  2   title          3701 non-null   object
#  3   description    3701 non-null   object
#  4   tags           3701 non-null   object
#  5   publishedAt    3701 non-null   object
#  6   duration       3701 non-null   object
#  7   definition     3701 non-null   object
#  8   caption        3701 non-null   bool
#  9   viewCount      3701 non-null   int64
#  10  likeCount      3701 non-null   float64
#  11  favoriteCount  3701 non-null   int64
#  12  commentCount   3701 non-null   float64
# dtypes: bool(1), float64(2), int64(2), object(8)
# memory usage: 350.7+ KB

# %% [markdown]
# tags should be counted, publishedAt should be date, duration should be time, likeCount and commentCount should be int.

# %%
#converting columns to numerical values
num_cols = ['viewCount', 'likeCount', 'favoriteCount','commentCount']
df[num_cols] = df[num_cols].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3701 entries, 0 to 3700
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       3701 non-null   object
#  1   channelTitle   3701 non-null   object
#  2   title          3701 non-null   object
#  3   description    3701 non-null   object
#  4   tags           3701 non-null   object
#  5   publishedAt    3701 non-null   object
#  6   duration       3701 non-null   object
#  7   definition     3701 non-null   object
#  8   caption        3701 non-null   bool
#  9   viewCount      3701 non-null   int64
#  10  likeCount      3701 non-null   float64
#  11  favoriteCount  3701 non-null   int64
#  12  commentCount   3701 non-null   float64
# dtypes: bool(1), float64(2), int64(2), object(8)
# memory usage: 350.7+ KB

# %% [markdown]
# #### Feature Engineering

# %%
df['publishedAt'].head(5)
# Out:
# 0    2022-07-28T11:26:27Z
# 1    2022-07-04T05:33:31Z
# 2    2022-07-01T17:23:48Z
# 3    2022-07-01T17:22:30Z
# 4    2022-07-01T16:21:41Z
# Name: publishedAt, dtype: object

# %%
df['publishedAt'] =  df['publishedAt'].apply(lambda x: parser.parse(x)) 
df['publishedDay'] = df['publishedAt'].apply(lambda x: x.strftime("%A"))
df['publishedMonth'] = df['publishedAt'].apply(lambda x: x.strftime("%m"))

# %% [markdown]
# Note: Datetime should be posted depending on their own timezones

# %%
#change format of duration column
df['duration_sec'] = df['duration'].apply(lambda x : isodate.parse_duration(x))
df['duration_sec'] = df['duration_sec'].astype('timedelta64[s]')

# %%
df['duration_min'] = df['duration_sec'].apply(lambda x : round(x/60))

# %%
df.head(5)
# Out:
#       video_id    channelTitle  \
# 0  kBHds-isexQ  Peak Performer
# 1  x-0xqKDfgdg  Peak Performer
# 2  Ousj-3KKYm0  Peak Performer
# 3  xs3UXvPFiMs  Peak Performer
# 4  Q7nnSj5Ied8  Peak Performer
#
#                                                title             description  \
# 0  07/2022 – Training with Peak on 50 cm (Interme...          No Description
# 1  MAY2022 – World Agility Open (WAO) – Nadine Al...  www.peak-performer.com
# 2            Steppach 06/2022 | Nadine Alshut & Nuii  www.peak-performer.com
# 3         Steppach 06/2022 | Nadine Alshut & Pashion  www.peak-performer.com
# 4           Steppach 06/2022 | Nadine Alshut & Cinna  www.peak-performer.com
#
#                                                 tags  \
# 0  ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 1  ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 2  ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 3  ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 4  ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
#
#                 publishedAt duration definition  caption  viewCount  \
# 0 2022-07-28 11:26:27+00:00  PT2M30S         hd    False        595
# 1 2022-07-04 05:33:31+00:00  PT3M47S         hd    False        346
# 2 2022-07-01 17:23:48+00:00  PT2M27S         hd    False        433
# 3 2022-07-01 17:22:30+00:00  PT2M23S         hd    False        292
# 4 2022-07-01 16:21:41+00:00  PT3M18S         hd    False        334
#
#    likeCount  favoriteCount  commentCount publishedDay publishedMonth  \
# 0       16.0              0           0.0     Thursday             07
# 1       13.0              0           0.0       Monday             07
# 2        6.0              0           0.0       Friday             07
# 3       11.0              0           0.0       Friday             07
# 4       12.0              0           2.0       Friday             07
#
#    duration_sec  duration_min
# 0         150.0             2
# 1         227.0             4
# 2         147.0             2
# 3         143.0             2
# 4         198.0             3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3701 entries, 0 to 3700
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        3701 non-null   object
#  1   channelTitle    3701 non-null   object
#  2   title           3701 non-null   object
#  3   description     3701 non-null   object
#  4   tags            3701 non-null   object
#  5   publishedAt     3701 non-null   datetime64[ns, tzutc()]
#  6   duration        3701 non-null   object
#  7   definition      3701 non-null   object
#  8   caption         3701 non-null   bool
#  9   viewCount       3701 non-null   int64
#  10  likeCount       3701 non-null   float64
#  11  favoriteCount   3701 non-null   int64
#  12  commentCount    3701 non-null   float64
#  13  publishedDay    3701 non-null   object
#  14  publishedMonth  3701 non-null   object
#  15  duration_sec    3701 non-null   float64
#  16  duration_min    3701 non-null   int64
# dtypes: bool(1), datetime64[ns, tzutc()](1), float64(3), int64(3), object(9)
# memory usage: 466.4+ KB

# %%
df['tags_list'] = df['tags'].apply(lambda x : x.strip("[]").replace("'","").split(', '))

# %%
df['tags_count'] = df['tags_list'].apply(lambda x : len(x))

# %% [markdown]
# Feature engineering like and comment ratio per views

# %%
df['likeRatio'] = df['likeCount']/df['viewCount'] * 1000

# %%
df['commentRatio'] = df['commentCount']/df['viewCount'] * 1000

# %% [markdown]
# Feature engeering title

# %%
df['title_length'] = df['title'].apply(lambda x: len(x))

# %%
df.head(2)
# Out:
#       video_id    channelTitle  \
# 0  kBHds-isexQ  Peak Performer
# 1  x-0xqKDfgdg  Peak Performer
#
#                                                title             description  \
# 0  07/2022 – Training with Peak on 50 cm (Interme...          No Description
# 1  MAY2022 – World Agility Open (WAO) – Nadine Al...  www.peak-performer.com
#
#                                                 tags  \
# 0  ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
# 1  ['swiss', 'paws', 'sheltie', 'chaim', 'raichu'...
#
#                 publishedAt duration definition  caption  viewCount  ...  \
# 0 2022-07-28 11:26:27+00:00  PT2M30S         hd    False        595  ...
# 1 2022-07-04 05:33:31+00:00  PT3M47S         hd    False        346  ...
#
#    commentCount  publishedDay  publishedMonth duration_sec duration_min  \
# 0           0.0      Thursday              07        150.0            2
# 1           0.0        Monday              07        227.0            4
#
#                                            tags_list  tags_count  likeRatio  \
# 0  [swiss, paws, sheltie, chaim, raichu, cinna, a...          20  26.890756
# 1  [swiss, paws, sheltie, chaim, raichu, cinna, a...          20  37.572254
#
#    commentRatio  title_length
# 0           0.0            52
# 1           0.0            57
#
# [2 rows x 22 columns]

# %% [markdown]
# Separate video data into different tiers

# %%
df_normal = df[df['channelTitle'].isin(normal_ch)].drop('favoriteCount',axis=1)

# %%
df_premium = df[~df['channelTitle'].isin(normal_ch)].drop('favoriteCount',axis=1)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=df_normal.corr(),annot=True).set(title='Normal Channel Feature Correlation')
# Out:
# [Text(0.5, 1.0, 'Normal Channel Feature Correlation')]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=df_premium.corr(),annot=True).set(title='Premium Channel Feature Correlation')
# Out:
# [Text(0.5, 1.0, 'Premium Channel Feature Correlation')]

# %% [markdown]
# Check average tags per video per channel

# %%
df_normal.groupby(by='channelTitle').mean()['tags_count'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='channelTitle'>

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x='tags_count',y='viewCount',data=df_normal,hue='channelTitle',palette='colorblind')
sns.move_legend(ax, "upper right",bbox_to_anchor=(1,1))

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x='tags_count',y='viewCount',data=df_premium,hue='channelTitle',palette='colorblind')
sns.move_legend(ax, "upper right",bbox_to_anchor=(1, 1))

# %% [markdown]
# Investigate relationship between title length and view counts

# %%
#title length vs view
df_normal['title_length'] = df_normal['title'].apply(lambda x: len(x)) #move to feature engineering part

plt.figure(figsize=(12,6))
sns.scatterplot(x='title_length',y='viewCount',data=df_normal,hue='channelTitle',palette='colorblind')
# Out:
# <AxesSubplot:xlabel='title_length', ylabel='viewCount'>

# %% [markdown]
# comment count vs view count

# %%
plt.figure(figsize=(12,6))
sns.lmplot(x='commentCount',y='viewCount',data=df_normal)

# %%
plt.figure(figsize=(12,6))
sns.lmplot(x='commentCount',y='viewCount',data=df_premium)

# %% [markdown]
# observation: seems like there is a trend between view and comment - possibly due to youtube algorithm

# %%
plt.figure(figsize=(12,6))
sns.lmplot(x='likeCount',y='viewCount',data=df_normal)

# %%
plt.figure(figsize=(12,6))
sns.lmplot(x='likeCount',y='viewCount',data=df_premium)

# %% [markdown]
# #### Go back all data

# %%
#EDA part
#view distribution in each channel
#viewcount vs comment/like
#view to comment ratio or view to like ratio
#video duration matter?
#title length matter?
#wordcloud for title
#worldcloud for comment
#no. of tags - popular tags?
#days in week - note the timezone
#time of the day - note the timezone
#month ?

#things to note
#add more local channels
#positive comments? correlation of comments and title to say which topic is in demand

#can I create a video title suggestion model ?

# %%
stop_words = set(stopwords.words('english'))
df['title_no_stopwords'] = df['title'].apply(lambda x : [item for item in str(x).split() if item not in stop_words])

# %%
df['title_no_stopwords']
# Out:
# 0       [07/2022, –, Training, Peak, 50, cm, (Intermed...
# 1       [MAY2022, –, World, Agility, Open, (WAO), –, N...
# 2         [Steppach, 06/2022, |, Nadine, Alshut, &, Nuii]
# 3       [Steppach, 06/2022, |, Nadine, Alshut, &, Pash...
# 4        [Steppach, 06/2022, |, Nadine, Alshut, &, Cinna]
#                               ...
# 3696                                 [training, November]
# 3697                        [Heist, Royackers, Nov, 2013]
# 3698     [My, dog, hijack's, first, full, height, teeter]
# 3699    [Your, Agility, Questions, Answered:, Focus, o...
# 3700    [Start, line, question:, getting, dog, positio...
# Name: title_no_stopwords, Length: 3701, dtype: object

# %%
title_words = list([a for b in df['title_no_stopwords'].tolist() for a in b]) #I don't get this

# %%
title_words_str = ' '.join(title_words)

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(30,20))
    plt.imshow(wordcloud)
    plt.axis('off');
    
wordcloud = WordCloud(width=2000, 
                      height=1000, 
                      random_state=1, 
                      background_color='black',
                      colormap='magma',
                      collocations=False).generate(title_words_str)

plot_cloud(wordcloud)
